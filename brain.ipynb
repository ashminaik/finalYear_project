# %%
import numpy as np
import pandas as pd

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
import torch
import torch.optim as optim
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torchvision import models, datasets

# %%
base_directory = '/kaggle/input/brain-tumor-mri-dataset'
train, test = 'Training', 'Testing'
target_size = (224, 224)
random_state = 42
batch_size = 16
num_classes = 4
device = "cuda" if torch.cuda.is_available() else "cpu"
label_map = {
    'notumor': 0,
    'glioma': 1,
    'meningioma': 2,
    'pituitary': 3
}

# %%
categories = os.listdir(base_directory+'/'+train)
print(categories)
# Out:
# ['pituitary', 'notumor', 'meningioma', 'glioma']

# %%
def display_images(dataset_type, num_images=4, image_size=(224, 224)):

    dataset_path = os.path.join(base_directory, dataset_type)

    fig, axes = plt.subplots(len(categories), num_images, figsize=(15, 10))

    for row, category in enumerate(categories):
        category_path = os.path.join(dataset_path, category)
        image_filenames = random.sample(os.listdir(category_path), num_images)  # Select random images

        for col, image_filename in enumerate(image_filenames):
            while image_filename == '.DS_Store':
                image_filename = random.sample(os.listdir(category_path), 1)[0]
            image_path = os.path.join(category_path, image_filename)
            image = Image.open(image_path).resize(image_size)
            axes[row, col].imshow(image, cmap='gray')
            axes[row, col].axis('off')
            axes[row, col].set_title(f"{category}")

    plt.tight_layout()
    plt.show()

# %%
def plot_class_distribution(dataset_type):
    path = os.path.join(base_directory, dataset_type)
    counts = [len(os.listdir(os.path.join(path, cat))) for cat in categories]

    plt.bar(categories, counts, color = ['navy', 'teal', 'darkorange', 'crimson'])
    plt.xlabel("Class")
    plt.ylabel("Number of Images")
    plt.title(f"{dataset_type.capitalize()} Set Distribution")
    plt.show()

# %%
plot_class_distribution(train)

# %%
display_images(train)

# %%
plot_class_distribution(test)

# %%
display_images(test)

# %%
def create_dataset(path):
    my_list = []
    for category in categories:
        category_path = os.path.join(path, category)
        for file_name in os.listdir(category_path):
            file_path = os.path.join(category_path, file_name)
            # Ensure we're only adding image files
            if os.path.isfile(file_path) and file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                my_list.append([file_path, category])
    return pd.DataFrame(my_list, columns=['file_path', 'label'])

# %%
train_df = create_dataset(base_directory+'/'+train)
test_df = create_dataset(base_directory+'/'+test)

# %%
train_df['label'] = train_df['label'].map(label_map)
test_df['label'] = test_df['label'].map(label_map)

# %%
class ImageDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_path = self.dataframe.iloc[idx, 0]
        label = self.dataframe.iloc[idx, 1]
        img = Image.open(img_path).convert('RGB')

        if self.transform:
            img = self.transform(img)

        return img, label

# %%
train_transform = transforms.Compose([

   transforms.Resize(target_size),
   transforms.RandomHorizontalFlip(),
   transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
   transforms.ColorJitter(brightness=(0.8, 1.2)),
   transforms.RandomRotation(10),
   transforms.ToTensor(),
   transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
test_df_split, val_df_split = train_test_split(test_df, test_size=0.5, random_state=random_state)
# Reset indices for consistency
test_df_split = test_df_split.reset_index(drop=True)
val_df_split = val_df_split.reset_index(drop=True)

# %%
train_dataset = ImageDataset(train_df, transform=train_transform)
val_dataset = ImageDataset(val_df_split, transform=test_transform)
test_dataset = ImageDataset(test_df_split, transform=test_transform)

# DataLoader
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class BrainTumorCNN(nn.Module):
    def __init__(self, num_classes=4):
        super(BrainTumorCNN, self).__init__()

        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(0.5)
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(256, 256, kernel_size=3, padding=1)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256 * 7 * 7, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(self.relu(self.conv1(x)))
        x = self.pool(self.relu(self.conv2(x)))
        x = self.pool(self.relu(self.conv3(x)))
        x = self.pool(self.relu(self.conv4(x)))
        x = self.pool(self.relu(self.conv5(x)))

        x = self.flatten(x)
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.fc2(x)

        return x

# %%
model = BrainTumorCNN(num_classes=4).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0007)

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=10, name='model', patience=7):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    best_val_loss = float("inf")
    tolerance = 0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_acc = 100 * correct_train / total_train
        model.eval()
        val_loss = 0.0
        correct_val = 0
        total_val = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        val_loss = val_loss / len(val_loader)
        val_acc = 100 * correct_val / total_val

        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['val_loss'].append(val_loss)
        history['val_acc'].append(val_acc)

        print(f"Epoch [{epoch+1}/{num_epochs}]")
        print(f"Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.2f}%")
        print(f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.2f}%")
        print("#" * 80)
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), f'best_brain_tumor_{name}.pth')
            tolerance = 0
        else:
            tolerance += 1
            if tolerance >= patience:
                print(f"Early stopping triggered after {epoch+1} epochs.")
                break

    return history

# %%
def test_model(model, test_loader, num_images_to_show=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    correct = 0
    total = 0

    all_preds = []
    all_labels = []
    all_images = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_images.extend(images.cpu())

    test_acc = 100 * correct / total

    cm = confusion_matrix(all_labels, all_preds)

    print(f"Test Accuracy: {test_acc:.2f}%\n")

    # Print classification report
    print("Classification Report:\n")
    print(classification_report(all_labels, all_preds, target_names=categories))

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=categories, yticklabels=categories)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

# %%
print("Starting training...")
history = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs=60)
# Out:
# Starting training...
# Epoch [1/60]
# Train Loss: 0.9682, Train Accuracy: 58.23%
# Val Loss: 0.7380, Val Accuracy: 69.21%
# ################################################################################
# Epoch [2/60]
# Train Loss: 0.6357, Train Accuracy: 73.69%
# Val Loss: 0.5855, Val Accuracy: 75.61%
# ################################################################################
# Epoch [3/60]
# Train Loss: 0.5322, Train Accuracy: 79.32%
# Val Loss: 0.4816, Val Accuracy: 82.01%
# ################################################################################
# Epoch [4/60]
# Train Loss: 0.4395, Train Accuracy: 83.56%
# Val Loss: 0.3620, Val Accuracy: 86.13%
# ################################################################################
# Epoch [5/60]
# Train Loss: 0.3577, Train Accuracy: 86.76%
# Val Loss: 0.2961, Val Accuracy: 89.18%
# ################################################################################
# Epoch [6/60]
# Train Loss: 0.3108, Train Accuracy: 88.50%
# Val Loss: 0.3547, Val Accuracy: 84.91%
# ################################################################################
# Epoch [7/60]
# Train Loss: 0.2708, Train Accuracy: 89.78%
# Val Loss: 0.2878, Val Accuracy: 89.79%
# ################################################################################
# Epoch [8/60]
# Train Loss: 0.2463, Train Accuracy: 91.23%
# Val Loss: 0.2440, Val Accuracy: 91.31%
# ################################################################################
# Epoch [9/60]
# Train Loss: 0.2183, Train Accuracy: 92.16%
# Val Loss: 0.1720, Val Accuracy: 93.60%
# ################################################################################
# Epoch [10/60]
# Train Loss: 0.1849, Train Accuracy: 93.63%
# Val Loss: 0.2025, Val Accuracy: 92.38%
# ################################################################################
# Epoch [11/60]
# Train Loss: 0.1776, Train Accuracy: 93.61%
# Val Loss: 0.1378, Val Accuracy: 94.82%
# ################################################################################
# Epoch [12/60]
# Train Loss: 0.1753, Train Accuracy: 93.98%
# Val Loss: 0.1831, Val Accuracy: 92.99%
# ################################################################################
# Epoch [13/60]
# Train Loss: 0.1610, Train Accuracy: 94.50%
# Val Loss: 0.1172, Val Accuracy: 96.04%
# ################################################################################
# Epoch [14/60]
# Train Loss: 0.1455, Train Accuracy: 94.87%
# Val Loss: 0.0897, Val Accuracy: 96.95%
# ################################################################################
# Epoch [15/60]
# Train Loss: 0.1361, Train Accuracy: 95.31%
# Val Loss: 0.0788, Val Accuracy: 97.56%
# ################################################################################
# Epoch [16/60]
# Train Loss: 0.1341, Train Accuracy: 95.55%
# Val Loss: 0.1102, Val Accuracy: 96.19%
# ################################################################################
# Epoch [17/60]
# Train Loss: 0.1230, Train Accuracy: 95.62%
# Val Loss: 0.0765, Val Accuracy: 97.26%
# ################################################################################
# Epoch [18/60]
# Train Loss: 0.1158, Train Accuracy: 95.92%
# Val Loss: 0.0584, Val Accuracy: 97.87%
# ################################################################################
# Epoch [19/60]
# Train Loss: 0.0939, Train Accuracy: 96.74%
# Val Loss: 0.0648, Val Accuracy: 97.26%
# ################################################################################
# Epoch [20/60]
# Train Loss: 0.1040, Train Accuracy: 96.45%
# Val Loss: 0.0733, Val Accuracy: 97.41%
# ################################################################################
# Epoch [21/60]
# Train Loss: 0.1163, Train Accuracy: 96.22%
# Val Loss: 0.0600, Val Accuracy: 98.17%
# ################################################################################
# Epoch [22/60]
# Train Loss: 0.0955, Train Accuracy: 96.53%
# Val Loss: 0.0445, Val Accuracy: 98.32%
# ################################################################################
# Epoch [23/60]
# Train Loss: 0.0958, Train Accuracy: 96.57%
# Val Loss: 0.0700, Val Accuracy: 97.26%
# ################################################################################
# Epoch [24/60]
# Train Loss: 0.0880, Train Accuracy: 97.16%
# Val Loss: 0.0697, Val Accuracy: 97.41%
# ################################################################################
# Epoch [25/60]
# Train Loss: 0.0937, Train Accuracy: 96.94%
# Val Loss: 0.0437, Val Accuracy: 98.48%
# ################################################################################
# Epoch [26/60]
# Train Loss: 0.0780, Train Accuracy: 97.32%
# Val Loss: 0.1248, Val Accuracy: 95.88%
# ################################################################################
# Epoch [27/60]
# Train Loss: 0.1070, Train Accuracy: 96.38%
# Val Loss: 0.0806, Val Accuracy: 96.19%
# ################################################################################
# Epoch [28/60]
# Train Loss: 0.0714, Train Accuracy: 97.72%
# Val Loss: 0.0558, Val Accuracy: 97.87%
# ################################################################################
# Epoch [29/60]
# Train Loss: 0.0768, Train Accuracy: 97.41%
# Val Loss: 0.0287, Val Accuracy: 99.09%
# ################################################################################
# Epoch [30/60]
# Train Loss: 0.0583, Train Accuracy: 98.07%
# Val Loss: 0.0438, Val Accuracy: 98.32%
# ################################################################################
# Epoch [31/60]
# Train Loss: 0.0700, Train Accuracy: 97.58%
# Val Loss: 0.0405, Val Accuracy: 98.63%
# ################################################################################
# Epoch [32/60]
# Train Loss: 0.0756, Train Accuracy: 97.36%
# Val Loss: 0.0558, Val Accuracy: 98.63%
# ################################################################################
# Epoch [33/60]
# Train Loss: 0.0690, Train Accuracy: 97.41%
# Val Loss: 0.0739, Val Accuracy: 97.26%
# ################################################################################
# Epoch [34/60]
# Train Loss: 0.0681, Train Accuracy: 97.85%
# Val Loss: 0.1382, Val Accuracy: 94.21%
# ################################################################################
# Epoch [35/60]
# Train Loss: 0.0731, Train Accuracy: 97.83%
# Val Loss: 0.0414, Val Accuracy: 98.78%
# ################################################################################
# Epoch [36/60]
# Train Loss: 0.0596, Train Accuracy: 98.21%
# Val Loss: 0.0525, Val Accuracy: 98.78%
# ################################################################################
# Early stopping triggered after 36 epochs.

# %%
def plot_training_history(history, model_name="model"):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history['train_loss'], label='Train Loss')
    plt.plot(history['val_loss'], label='Val Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history['train_acc'], label='Train Acc')
    plt.plot(history['val_acc'], label='Val Acc')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy (%)')
    plt.legend()
    plt.show()

# %%
plot_training_history(history, model_name="CustomCNN")

# %%
print("\nLoading best model for testing...")
model.load_state_dict(torch.load('best_brain_tumor_model.pth'))
test_model(model, test_loader)
# Out:
# Loading best model for testing...
# Test Accuracy: 98.78%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    pituitary       1.00      1.00      1.00       197
#      notumor       1.00      0.97      0.98       151
#   meningioma       0.97      0.98      0.98       158
#       glioma       0.97      1.00      0.99       149
#
#     accuracy                           0.99       655
#    macro avg       0.99      0.99      0.99       655
# weighted avg       0.99      0.99      0.99       655

# %%
def visualize_predictions(model, test_loader, num_images=10):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    model.eval()

    correct_images, incorrect_images = [], []
    correct_labels, incorrect_labels = [], []
    correct_preds, incorrect_preds = [], []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            for i in range(len(predicted)):
                if predicted[i] == labels[i]:
                    correct_images.append(images[i])
                    correct_labels.append(labels[i].cpu().item())
                    correct_preds.append(predicted[i].cpu().item())
                else:
                    incorrect_images.append(images[i])
                    incorrect_labels.append(labels[i].cpu().item())
                    incorrect_preds.append(predicted[i].cpu().item())


    mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1).to(device)
    std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1).to(device)

    num_cols = num_images // 2
    plt.figure(figsize=(15, 7))

    for i, img_tensor in enumerate(correct_images[:num_images // 2]):
        img_tensor = img_tensor * std + mean
        img = np.clip(img_tensor.permute(1, 2, 0).cpu().numpy(), 0, 1)
        plt.subplot(2, num_cols, i + 1)
        plt.imshow(img)
        plt.title(f"True: {categories[correct_labels[i]]}\nPred: {categories[correct_preds[i]]}", color='green', fontsize=15)
        plt.axis('off')

    for i, img_tensor in enumerate(incorrect_images[:num_images // 2]):
        if i >= len(incorrect_images):
            plt.axis('off')
            continue
        img_tensor = img_tensor * std + mean
        img = np.clip(img_tensor.permute(1, 2, 0).cpu().numpy(), 0, 1)
        plt.subplot(2, num_cols, num_cols + i + 1)
        plt.imshow(img)
        plt.title(f"True: {categories[incorrect_labels[i]]}\nPred: {categories[incorrect_preds[i]]}", color='red', fontsize=15)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
visualize_predictions(model, test_loader, 8)

# %%
model2 = models.resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 154MB/s]

# %%
for param in model2.parameters():
    param.requires_grad = False

# %%
num_ftrs = model2.fc.in_features
model2.fc = nn.Sequential(
    nn.Linear(num_ftrs, 512),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(512, 4)
)

# %%
model2 = model2.to(device)

# %%
optimizer = optim.Adam(model2.fc.parameters(), lr=0.001)

# %%
print("Starting training...")
history = train_model(model2, train_loader, val_loader, criterion, optimizer, num_epochs=60, name='resnet18')
# Out:
# Starting training...
# Epoch [1/60]
# Train Loss: 0.6851, Train Accuracy: 72.18%
# Val Loss: 0.5109, Val Accuracy: 79.42%
# ################################################################################
# Epoch [2/60]
# Train Loss: 0.5141, Train Accuracy: 80.41%
# Val Loss: 0.4692, Val Accuracy: 81.55%
# ################################################################################
# Epoch [3/60]
# Train Loss: 0.4738, Train Accuracy: 81.92%
# Val Loss: 0.4258, Val Accuracy: 82.32%
# ################################################################################
# Epoch [4/60]
# Train Loss: 0.4522, Train Accuracy: 83.32%
# Val Loss: 0.4079, Val Accuracy: 84.60%
# ################################################################################
# Epoch [5/60]
# Train Loss: 0.4413, Train Accuracy: 82.88%
# Val Loss: 0.3594, Val Accuracy: 86.13%
# ################################################################################
# Epoch [6/60]
# Train Loss: 0.4147, Train Accuracy: 84.00%
# Val Loss: 0.3994, Val Accuracy: 83.84%
# ################################################################################
# Epoch [7/60]
# Train Loss: 0.4203, Train Accuracy: 83.91%
# Val Loss: 0.3904, Val Accuracy: 84.45%
# ################################################################################
# Epoch [8/60]
# Train Loss: 0.3890, Train Accuracy: 85.50%
# Val Loss: 0.3735, Val Accuracy: 85.52%
# ################################################################################
# Epoch [9/60]
# Train Loss: 0.3862, Train Accuracy: 85.43%
# Val Loss: 0.3585, Val Accuracy: 86.74%
# ################################################################################
# Epoch [10/60]
# Train Loss: 0.4073, Train Accuracy: 84.91%
# Val Loss: 0.3796, Val Accuracy: 85.52%
# ################################################################################
# Epoch [11/60]
# Train Loss: 0.3827, Train Accuracy: 85.26%
# Val Loss: 0.3427, Val Accuracy: 86.13%
# ################################################################################
# Epoch [12/60]
# Train Loss: 0.3633, Train Accuracy: 85.77%
# Val Loss: 0.3426, Val Accuracy: 85.52%
# ################################################################################
# Epoch [13/60]
# Train Loss: 0.3719, Train Accuracy: 86.08%
# Val Loss: 0.3644, Val Accuracy: 85.67%
# ################################################################################
# Epoch [14/60]
# Train Loss: 0.3707, Train Accuracy: 86.45%
# Val Loss: 0.3182, Val Accuracy: 87.50%
# ################################################################################
# Epoch [15/60]
# Train Loss: 0.3735, Train Accuracy: 85.92%
# Val Loss: 0.2832, Val Accuracy: 89.48%
# ################################################################################
# Epoch [16/60]
# Train Loss: 0.3578, Train Accuracy: 86.13%
# Val Loss: 0.3074, Val Accuracy: 88.26%
# ################################################################################
# Epoch [17/60]
# Train Loss: 0.3458, Train Accuracy: 87.20%
# Val Loss: 0.3508, Val Accuracy: 87.20%
# ################################################################################
# Epoch [18/60]
# Train Loss: 0.3591, Train Accuracy: 85.96%
# Val Loss: 0.3395, Val Accuracy: 85.98%
# ################################################################################
# Epoch [19/60]
# Train Loss: 0.3538, Train Accuracy: 86.61%
# Val Loss: 0.3547, Val Accuracy: 85.52%
# ################################################################################
# Epoch [20/60]
# Train Loss: 0.3508, Train Accuracy: 86.82%
# Val Loss: 0.2887, Val Accuracy: 88.57%
# ################################################################################
# Epoch [21/60]
# Train Loss: 0.3428, Train Accuracy: 86.68%
# Val Loss: 0.2807, Val Accuracy: 88.57%
# ################################################################################
# Epoch [22/60]
# Train Loss: 0.3343, Train Accuracy: 87.08%
# Val Loss: 0.2980, Val Accuracy: 88.87%
# ################################################################################
# Epoch [23/60]
# Train Loss: 0.3288, Train Accuracy: 87.11%
# Val Loss: 0.3101, Val Accuracy: 87.65%
# ################################################################################
# Epoch [24/60]
# Train Loss: 0.3501, Train Accuracy: 86.83%
# Val Loss: 0.2790, Val Accuracy: 89.02%
# ################################################################################
# Epoch [25/60]
# Train Loss: 0.3238, Train Accuracy: 88.10%
# Val Loss: 0.2799, Val Accuracy: 89.79%
# ################################################################################
# Epoch [26/60]
# Train Loss: 0.3221, Train Accuracy: 87.94%
# Val Loss: 0.3263, Val Accuracy: 86.89%
# ################################################################################
# Epoch [27/60]
# Train Loss: 0.3338, Train Accuracy: 87.08%
# Val Loss: 0.2942, Val Accuracy: 88.72%
# ################################################################################
# Epoch [28/60]
# Train Loss: 0.3091, Train Accuracy: 87.99%
# Val Loss: 0.2639, Val Accuracy: 89.79%
# ################################################################################
# Epoch [29/60]
# Train Loss: 0.3316, Train Accuracy: 87.43%
# Val Loss: 0.2911, Val Accuracy: 88.72%
# ################################################################################
# Epoch [30/60]
# Train Loss: 0.3311, Train Accuracy: 87.59%
# Val Loss: 0.2929, Val Accuracy: 88.57%
# ################################################################################
# Epoch [31/60]
# Train Loss: 0.3205, Train Accuracy: 88.13%
# Val Loss: 0.2719, Val Accuracy: 88.57%
# ################################################################################
# Epoch [32/60]
# Train Loss: 0.3234, Train Accuracy: 87.75%
# Val Loss: 0.2694, Val Accuracy: 88.87%
# ################################################################################
# Epoch [33/60]
# Train Loss: 0.3203, Train Accuracy: 87.92%
# Val Loss: 0.2670, Val Accuracy: 88.11%
# ################################################################################
# Epoch [34/60]
# Train Loss: 0.2947, Train Accuracy: 88.81%
# Val Loss: 0.2801, Val Accuracy: 88.57%
# ################################################################################
# Epoch [35/60]
# Train Loss: 0.3094, Train Accuracy: 88.04%
# Val Loss: 0.2710, Val Accuracy: 89.79%
# ################################################################################
# Early stopping triggered after 35 epochs.

# %%
plot_training_history(history, model_name="ResNet18")

# %%
print("\nLoading best model for testing...")
model2.load_state_dict(torch.load('best_brain_tumor_resnet18.pth'))
test_model(model2, test_loader)
# Out:
# Loading best model for testing...
# Test Accuracy: 89.31%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    pituitary       0.93      0.98      0.95       197
#      notumor       0.89      0.83      0.86       151
#   meningioma       0.83      0.76      0.79       158
#       glioma       0.91      0.99      0.95       149
#
#     accuracy                           0.89       655
#    macro avg       0.89      0.89      0.89       655
# weighted avg       0.89      0.89      0.89       655

# %%
visualize_predictions(model2, test_loader, 8)

# %%
for name, param in model2.named_parameters():
    if 'layer4' in name or 'layer3' in name or 'fc' in name:
        param.requires_grad = True

# %%
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model2.parameters()), lr=1e-4)

# %%
print("Starting training...")
history = train_model(model2, train_loader, val_loader, criterion, optimizer, num_epochs=30, name='resnet18_finetuned')
# Out:
# Starting training...
# Epoch [1/30]
# Train Loss: 0.3138, Train Accuracy: 89.01%
# Val Loss: 0.1982, Val Accuracy: 92.99%
# ################################################################################
# Epoch [2/30]
# Train Loss: 0.1725, Train Accuracy: 93.86%
# Val Loss: 0.1721, Val Accuracy: 92.84%
# ################################################################################
# Epoch [3/30]
# Train Loss: 0.1671, Train Accuracy: 94.33%
# Val Loss: 0.1340, Val Accuracy: 95.12%
# ################################################################################
# Epoch [4/30]
# Train Loss: 0.1193, Train Accuracy: 96.17%
# Val Loss: 0.0715, Val Accuracy: 97.41%
# ################################################################################
# Epoch [5/30]
# Train Loss: 0.1064, Train Accuracy: 96.43%
# Val Loss: 0.0875, Val Accuracy: 96.80%
# ################################################################################
# Epoch [6/30]
# Train Loss: 0.0697, Train Accuracy: 97.71%
# Val Loss: 0.0539, Val Accuracy: 98.17%
# ################################################################################
# Epoch [7/30]
# Train Loss: 0.0925, Train Accuracy: 97.16%
# Val Loss: 0.0654, Val Accuracy: 97.87%
# ################################################################################
# Epoch [8/30]
# Train Loss: 0.0697, Train Accuracy: 97.95%
# Val Loss: 0.0237, Val Accuracy: 99.09%
# ################################################################################
# Epoch [9/30]
# Train Loss: 0.0452, Train Accuracy: 98.53%
# Val Loss: 0.0362, Val Accuracy: 98.93%
# ################################################################################
# Epoch [10/30]
# Train Loss: 0.0536, Train Accuracy: 98.23%
# Val Loss: 0.0344, Val Accuracy: 98.17%
# ################################################################################
# Epoch [11/30]
# Train Loss: 0.0417, Train Accuracy: 98.67%
# Val Loss: 0.0559, Val Accuracy: 98.78%
# ################################################################################
# Epoch [12/30]
# Train Loss: 0.0515, Train Accuracy: 98.72%
# Val Loss: 0.0404, Val Accuracy: 98.63%
# ################################################################################
# Epoch [13/30]
# Train Loss: 0.0350, Train Accuracy: 98.81%
# Val Loss: 0.0139, Val Accuracy: 99.39%
# ################################################################################
# Epoch [14/30]
# Train Loss: 0.0491, Train Accuracy: 98.58%
# Val Loss: 0.1494, Val Accuracy: 96.49%
# ################################################################################
# Epoch [15/30]
# Train Loss: 0.0592, Train Accuracy: 98.51%
# Val Loss: 0.0293, Val Accuracy: 99.09%
# ################################################################################
# Epoch [16/30]
# Train Loss: 0.0333, Train Accuracy: 98.98%
# Val Loss: 0.0105, Val Accuracy: 99.70%
# ################################################################################
# Epoch [17/30]
# Train Loss: 0.0507, Train Accuracy: 98.60%
# Val Loss: 0.0436, Val Accuracy: 98.63%
# ################################################################################
# Epoch [18/30]
# Train Loss: 0.0253, Train Accuracy: 99.25%
# Val Loss: 0.0181, Val Accuracy: 99.70%
# ################################################################################
# Epoch [19/30]
# Train Loss: 0.0277, Train Accuracy: 99.12%
# Val Loss: 0.0188, Val Accuracy: 99.09%
# ################################################################################
# Epoch [20/30]
# Train Loss: 0.0153, Train Accuracy: 99.46%
# Val Loss: 0.0594, Val Accuracy: 98.78%
# ################################################################################
# Epoch [21/30]
# Train Loss: 0.0326, Train Accuracy: 98.91%
# Val Loss: 0.0437, Val Accuracy: 98.48%
# ################################################################################
# Epoch [22/30]
# Train Loss: 0.0233, Train Accuracy: 99.23%
# Val Loss: 0.0330, Val Accuracy: 99.54%
# ################################################################################
# Epoch [23/30]
# Train Loss: 0.0475, Train Accuracy: 98.76%
# Val Loss: 0.0199, Val Accuracy: 99.24%
# ################################################################################
# Early stopping triggered after 23 epochs.

# %%
plot_training_history(history, model_name="ResNet18-Finetuned")

# %%
print("\nLoading best model for testing...")
model2.load_state_dict(torch.load('best_brain_tumor_resnet18_finetuned.pth'))
test_model(model2, test_loader)
# Out:
# Loading best model for testing...
# Test Accuracy: 100.00%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    pituitary       1.00      1.00      1.00       197
#      notumor       1.00      1.00      1.00       151
#   meningioma       1.00      1.00      1.00       158
#       glioma       1.00      1.00      1.00       149
#
#     accuracy                           1.00       655
#    macro avg       1.00      1.00      1.00       655
# weighted avg       1.00      1.00      1.00       655

# %%
visualize_predictions(model2, test_loader, 8)
